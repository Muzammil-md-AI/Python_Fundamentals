# %%
countries = ['india','usa','uk','spain']

# %%
# Removing elements from the list

# %%
print(countries)
# Out:
# ['india', 'usa', 'uk', 'spain']

# %%
type(countries)
# Out:
# list

# %%
del countries[3]

# %%
print(countries)
# Out:
# ['india', 'usa', 'uk']

# %%
print(countries)
# Out:
# ['india', 'usa', 'uk']

# %%
countries.append('china')

# %%
countries.append('spain')

# %%
print(countries)
# Out:
# ['india']

# %%
countries.pop() # Here the elements are not being deleted permanenetly, 
                #it will be creating a carbon copy of the deleted items internally
# Out:
# 'china'

# %%
print(countries)
# Out:
# ['india', 'usa', 'uk', 'china', 'china']

# %%
del countries[-1]

# %%
print(countries)
# Out:
# ['india']

# %%
print(countries)
# Out:
# ['india']

# %%
states = ['AP','TG','MP','KL','TN','KA']

# %%
print(states)
# Out:
# ['AP', 'TG', 'MP', 'KL', 'TN', 'KA']

# %%
 del states[3]

# %%
print(states)
# Out:
# ['AP', 'TG', 'MP', 'TN', 'KA']

# %%
states.append('punjab')

# %%
print(states)
# Out:
# ['AP', 'TG', 'MP', 'TN', 'KA', 'punjab']

# %%
del states[-2]

# %%
print(states)
# Out:
# ['AP', 'TG', 'MP', 'TN', 'punjab']

# %%
del states[-1]

# %%
print(states)
# Out:
# ['AP', 'TG', 'MP', 'TN']

# %%
states.append('goa')

# %%
print(states)
# Out:
# ['AP', 'TG', 'MP', 'TN', 'goa']

# %%
states.pop()
# Out:
# 'goa'

# %%
states.pop(0)
# Out:
# 'AP'

# %%
print(states)
# Out:
# ['TG', 'MP', 'TN']

# %%
states.pop(-2)
# Out:
# 'MP'

# %%
print(states)
# Out:
# ['TG', 'TN']

# %%
del states[1]

# %%
print(states)
# Out:
# ['TG']
