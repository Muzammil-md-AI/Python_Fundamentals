# %%
Variables in python
x =5 # assigning some value to x
y =4 # assigning some value to y

x+y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1aba994b7ab9> in <module>
# ----> 1 Variables in python
#       2 x =5 # assigning some value to x
#       3 y =4 # assigning some value to y
#       4
#       5 x+y
#
# NameError: name 'Variables' is not defined

# %%
x =5

# %%
y =4

# %%
x+y
# Out:
# 9

# %%
Muzammil = Ahmed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5e67835cdad8> in <module>
# ----> 1 Muzammil = Ahmed
#
# NameError: name 'Ahmed' is not defined

# %%
Muzammil =10

# %%
9 =Ahmed
# Out:
#   File "<ipython-input-12-80506dcdb11a>", line 1
#     9 =Ahmed
#             ^
# SyntaxError: can't assign to literal

# %%
print(Ahmed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-91aa2050cc67> in <module>
# ----> 1 print(Ahmed)
#
# NameError: name 'Ahmed' is not defined

# %%
Muzammil +10
# Out:
# 20

# %%
print(Muzammil)
# Out:
# 10

# %%
Muzammil -5
# Out:
# 5

# %%
Muzammil +2*10
# Out:
# 30

# %%
print(Muzammil)
# Out:
# 10

# %%
Muzammil +2-1
# Out:
# 11

# %%
2*2
# Out:
# 4

# %%
2*10
# Out:
# 20

# %%
Muzammil +2*10  # Here Muzammil means 10 + 2*10= 20....10+20= 30 is the ans
# Out:
# 30

# %%
00Ahmed =5
# Out:
#   File "<ipython-input-23-471db94c225f>", line 1
#     00Ahmed =5
#           ^
# SyntaxError: invalid syntax

# %%
A22hmed =5

# %%
Ahmed33 =5

# %%
print(ahmed33)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-03f21c697247> in <module>
# ----> 1 print(ahmed33)
#
# NameError: name 'ahmed33' is not defined

# %%
print(Ahmed33)
# Out:
# 5

# %%
Rules for declaring the variables in pyhton
* No spaces are allowed
* It should not start with a number
* We cannot use any spceial characters

# %%
Jameel@123 =44
# Out:
#   File "<ipython-input-29-d6e5b870c7ff>", line 1
#     Jameel@123 =44
#                   ^
# SyntaxError: can't assign to operator

# %%
Jameel_123 =44

# %%
print(Jameel_123)
# Out:
# 44

# %%
firstname = 'MohammeD'

# %%
firstname =Md
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-3dfb22d38198> in <module>
# ----> 1 firstname =Md
#
# NameError: name 'Md' is not defined

# %%
Firstname = 'Md'

# %%
Last_name = 'Muzammil'

# %%
print(firstname)
# Out:
# MohammeD

# %%
print(Firstname)
# Out:
# Md

# %%
print(Last_name)
# Out:
# Muzammil

# %%
Introduction to String data types
* A string is a series of characters.

* 3 possible ways to define string
1. ''---> single quotes
2. ""---> double quotes
3. """"""---> triple quotes

# %%
Address ='Tolichowki'

# %%
print(Address)
# Out:
# Tolichowki

# %%
City ="Hyderabad 500008"

# %%
print(City)
# Out:
# Hyderabad 500008

# %%
Country = """India"""

# %%
print(Country)
# Out:
# India

# %%
#=> String builtin methods

name = 'muzammil md'
print(name)
# Out:
# muzammil md

# %%
#Enhancement of code

print(name.tilte)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-bc0ae26728ea> in <module>
#       1 #Enhancement of code
#       2
# ----> 3 print(name.tilte)
#
# AttributeError: 'str' object has no attribute 'tilte'

# %%
print(name.title())
# Out:
# Muzammil Md

# %%
#Convert all the letters in capital

print(name.upper())
# Out:
# MUZAMMIL MD

# %%
#Convert all the letters in small

print(name.lower())
# Out:
# muzammil md

# %%
#Introduction to f strings

* It allows to create a place holder with curley braces{}
* Custom formatting
*Mainting the relation btn variables

# %%
first_name = 'tony'

# %%
last_name = 'stark'

# %%
full_name = f "{first_name} {last_name}"
print(full_name)
# Out:
#   File "<ipython-input-72-d9ca4ac4d078>", line 1
#     full_name = f "{first_name} {last_name}"
#                                            ^
# SyntaxError: invalid syntax

# %%
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-da5dda46fc16> in <module>
# ----> 1 print(full_name)
#
# NameError: name 'full_name' is not defined

# %%
firstname = "tony"

lastname = "stark"

fullname =  f"{firstname} {lastname}"

print(fullname)
# Out:
# tony stark

# %%
Hello ='I am'

# %%
how_are_you ='Good'

# %%
Howdy = f" {Hello} {how_are_you}"

# %%
print(Howdy)
# Out:
#  I am Good

# %%
#Enhancment code

# %%
print(Howdy.title())
# Out:
#  I Am Good

# %%
print(Howdy.upper())
# Out:
#  I AM GOOD

# %%
print(Howdy.lower())
# Out:
#  i am good
