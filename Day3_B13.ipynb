# %%
# Adding the white spaces to strings:

# %%
print("python")
# Out:
# python

# %%
print('\tpython')  #tab delimeter
# Out:
# 	python

# %%
print('LANGUAGES:\n~~~~~~~~~~ \n\npyhton\njava\nswift\nC\nC++\n----------\n\nMICROSOFT\n~~~~~~~~~:\n\nC#.Net\nASP.net\nVB.net')


# \n----> new line delimeter
# Out:
# LANGUAGES:
# ~~~~~~~~~~
#
# pyhton
# java
# swift
# C
# C++
# ----------
#
# MICROSOFT
# ~~~~~~~~~:
#
# C#.Net
# ASP.net
# VB.net

# %%
#Enhancement of code

# %%
print('Languages: \n\t\tpython\n\tjava\n\tswift\n\t\tC\n\t\tC++')  #\n\t---> newline tab delimeter
# Out:
# Languages:
# 		python
# 	java
# 	swift
# 		C
# 		C++

# %%
# here space which has created manually will also be occupying the storage capacity!

# %%
# Stripping the white spaces!

# %%
fav_lang = ' pyhton' #gap of left side

print(fav_lang)
# Out:
#  pyhton

# %%
fav_lang2 ='java  '  #gap of right side # it will occupy the storage

print(fav_lang2)
# Out:
# java

# %%
#How to eliminate the spaces?

print(fav_lang.lstrip())
# Out:
# pyhton

# %%
fav_lang.lstrip()
# Out:
# 'pyhton'

# %%
print(fav_lang2.lstrip())
# Out:
# java

# %%
fav_lang2.lstrip()
# Out:
# 'java  '

# %%
fav_lang2.rstrip()
# Out:
# 'java'

# %%
fav_lang3 = '  swift '

# %%
print(fav_lang3)
# Out:
#   swift

# %%
fav_lang3.strip()   # to reduce the time of execution we should NOT use this method, insted use other if we know the space side
# Out:
# 'swift'

# %%
## Introduction to operations in numbers: int Data type

# %%
int ---> integer

# %%
3+9
# Out:
# 12

# %%
65-5
# Out:
# 60

# %%
4*2
# Out:
# 8

# %%
5/2
# Out:
# 2.5

# %%
#*****Squaring the number

# %%
4**2
# Out:
# 16

# %%
3**3
# Out:
# 27

# %%
##** Decimal data type ## float data type

# %%
2.1+5.6
# Out:
# 7.699999999999999

# %%
***# How to verify the data type?

# %%
x =2.5
y =6.8

# %%
z =x+y
print(z)
# Out:
# 9.3

# %%
type(z)
# Out:
# float

# %%
first_name ='tony'

print(first_name)
# Out:
# tony

# %%
first_name.strip()
# Out:
# 'tony'

# %%
***# How to verify the data type?

# %%
type(first_name)
# Out:
# str

# %% [raw]
# str --->string
