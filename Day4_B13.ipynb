# %%
# Introduction to list data type
[] -->denoted -->square bracket

# %%
students =['sharuk,veena,vivek,anu,pornima,utsav']

# %%
print(students)
# Out:
# ['sharuk,veena,vivek,anu,pornima,utsav']

# %%
type(students) #validate data type
# Out:
# list

# %%
#Introduction to indexing
0,2,3,4,......

# %%
#How to access the elements in a list?

# %%
#access vivek name in the output

# %%
print(students)
# Out:
# ['sharuk,veena,vivek,anu,pornima,utsav']

# %%
print(students[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-b168c7aeee11> in <module>
# ----> 1 print(students[2])
#
# IndexError: list index out of range

# %%
students =['sharuk','veena','vivek','anu','pornima','utsav']  #have to use quotes

# %%
print(students)
# Out:
# ['sharuk', 'veena', 'vivek', 'anu', 'pornima', 'utsav']

# %%
print(students[2])
# Out:
# vivek

# %%
print(students[3][5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-3e3eec6cb985> in <module>
# ----> 1 print(students[3][5])
#
# IndexError: string index out of range

# %%
print(students[3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-87c72fe8c8dd> in <module>
# ----> 1 print(students[3,4])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
print(students)
# Out:
# ['sharuk', 'veena', 'vivek', 'anu', 'pornima', 'utsav']

# %%
print(students)
# Out:
# ['sharuk', 'veena', 'vivek', 'anu', 'pornima', 'utsav']

# %%
# from where the negative indexing will be starting from?
-1,-2,-3,-4.... 
utsav, pornima,anu....#from backward

# %%
#Achieve -ve indexing print utsav again

# %%
print(students[-1])
# Out:
# utsav

# %%
print(students[-6])
# Out:
# sharuk

# %%
print(students.title())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-64353c0424e5> in <module>
# ----> 1 print(students.title())
#
# AttributeError: 'list' object has no attribute 'title'

# %%
#Enhancement of code
print(students)
# Out:
# ['sharuk', 'veena', 'vivek', 'anu', 'pornima', 'utsav']

# %%
print(students[5].title())
# Out:
# Utsav

# %%
print(students[-6].title())
# Out:
# Sharuk

# %%
print(students[-3].upper())
# Out:
# ANU

# %%
print(students[1].lower())
# Out:
# veena

# %%
print(students[4].strip())
# Out:
# pornima

# %%
print(students[pornima].strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-72de5a4293a1> in <module>
# ----> 1 print(students[pornima].strip())
#
# NameError: name 'pornima' is not defined

# %%
print(students)
# Out:
# ['sharuk', 'veena', 'vivek', 'anu', 'pornima', 'utsav']

# %%
print(students[1].title().strip().upper()) # methods executes line by line
# Out:
# VEENA

# %%
my_games = ['cricket','football','tennis','basketball']

# %%
print(my_games)
# Out:
# ['cricket', 'football', 'tennis', 'basketball']

# %%
my_games[1] =badminton
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-7f95ace9e2a2> in <module>
# ----> 1 my_games[1] =badminton
#
# NameError: name 'badminton' is not defined

# %%
my_games[1] = 'badminton'  #change football to badminton

# %%
print(my_games)
# Out:
# ['cricket', 'badminton', 'tennis', 'basketball']

# %%
# Adding games to the list
print(my_games)
# Out:
# ['cricket', 'badminton', 'tennis', 'basketball']

# %%
my_games.append(football)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-1ae81b20af76> in <module>
# ----> 1 my_games.append(football)
#
# NameError: name 'football' is not defined

# %%
my_games.append('football') # append method adds the elements at the end of the list

# %%
print(my_games)
# Out:
# ['cricket', 'badminton', 'tennis', 'basketball', 'football']

# %%
#Insert hockey as a element at 1st place

# %%
my_games.insert('hockey')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-04fa10fa8843> in <module>
# ----> 1 my_games.insert('hockey')
#
# TypeError: insert() takes exactly 2 arguments (1 given)

# %%
my_games.insert(0,'hockey')

# %%
print(my_games)
# Out:
# ['hockey', 'cricket', 'badminton', 'tennis', 'basketball', 'football']

# %%
my_games.insert(-1,'hockey')    # here the element will not get add at last insted before lat

# %%
print(my_games)
# Out:
# ['hockey', 'cricket', 'badminton', 'tennis', 'basketball', 'hockey', 'football']

# %%
my_games.insert(-0,'rugby')   # here the element will get add at first in the list as -0 is given

# %%
print(my_games)
# Out:
# ['rugby', 'hockey', 'hockey', 'cricket', 'badminton', 'tennis', 'basketball', 'hockey', 'football']

# %%
# to add element at the end of the list append method is in use
